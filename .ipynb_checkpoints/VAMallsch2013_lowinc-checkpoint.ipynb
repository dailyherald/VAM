# %%
# Import all libraries needed for the tutorial
import pandas as pd
import numpy as np
import psycopg2
import sys
from pandas.io import sql
from pandas.io.sql import read_sql
import statsmodels.api as sm
import statsmodels.formula.api as smf

#pd.set_option('display.mpl_style', 'default') 
pd.set_option('display.width', 5000) 
pd.set_option('display.max_columns', 60)

import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

print('This Python version ' + sys.version)
print('Pandas version ' + pd.__version__)
# Out:
# This Python version 3.4.3 |Anaconda 2.2.0 (x86_64)| (default, Mar  6 2015, 12:07:41)
# [GCC 4.2.1 (Apple Inc. build 5577)]
# Pandas version 0.16.1

# %%
data = pd.DataFrame.from_csv('data2013.csv', index_col=None)
low = pd.DataFrame.from_csv('lowinc_2013.csv', index_col=None, encoding='ISO-8859-1')

# %%
data[:4]
# Out:
#    Unnamed: 0              school_name  school_id           network       grade  year  reading_studentsnumber  reading_vam reading_confidence  reading_percentile reading_color  math_studentsnumber  math_vam math_confidence  math_percentile math_color
# 0           0  GLOBAL CITIZENSHIP CHTR     400009  Charter/Contract  All Grades  2013                      93         -0.3        -1.3 to 0.7                  33        Yellow                   93      -0.8       -1.6 to 0               20        Red
# 1           1            LOCKE, A CHTR     400011  Charter/Contract  All Grades  2013                     213          0.7        -0.1 to 1.5                  81        Yellow                  213       1.0      0.5 to 1.5               87      Green
# 2           2          AMANDLA CHTR HS     400012  Charter/Contract  All Grades  2013                     243         -1.9       -2.7 to -1.1                   2           Red                  244      -1.4      -2 to -0.9                7        Red
# 3           3     ASPIRA CHTR - HAUGAN     400017  Charter/Contract  All Grades  2013                     562          0.4          -0.2 to 1                  71        Yellow                  561       0.5      0.2 to 0.9               73      Green

# %%
data.dtypes
# Out:
# Unnamed: 0                  int64
# school_name                object
# school_id                   int64
# network                    object
# grade                      object
# year                        int64
# reading_studentsnumber    float64
# reading_vam               float64
# reading_confidence         object
# reading_percentile        float64
# reading_color              object
# math_studentsnumber       float64
# math_vam                  float64
# math_confidence            object
# math_percentile           float64
# math_color                 object
# dtype: object

# %%
low[:4]
# Out:
#    school_id                                       School Name Total  LEP  LEPperc  IEP  IEPperc LowInc  LowIncperc
# 0     610229                              A.N. Pritzker School   676   55     8.14   62     9.17    376       55.62
# 1     610038                 Abraham Lincoln Elementary School   781   44     5.63   61     7.81    103       13.19
# 2     400009  Academy for Global Citizenship Elementary School   296   81    27.36   38    12.84    234       79.05
# 3     400146    Academy of Communication & Tech Charter School    81    0     0.00    6     7.41     74       91.36

# %%
low.dtypes
# Out:
# school_id        int64
# School Name     object
# Total           object
# LEP              int64
# LEPperc        float64
# IEP              int64
# IEPperc        float64
# LowInc          object
# LowIncperc     float64
# dtype: object

# %%
left = data
right = low
result = pd.merge(left, right, on='school_id')
result.shape
# Out:
# (488, 24)

# %%
result[:4]
# Out:
#    Unnamed: 0              school_name  school_id           network       grade  year  reading_studentsnumber  reading_vam reading_confidence  reading_percentile reading_color  math_studentsnumber  math_vam math_confidence  math_percentile math_color                                       School Name Total  LEP  LEPperc  IEP  IEPperc LowInc  LowIncperc
# 0           0  GLOBAL CITIZENSHIP CHTR     400009  Charter/Contract  All Grades  2013                      93         -0.3        -1.3 to 0.7                  33        Yellow                   93      -0.8       -1.6 to 0               20        Red  Academy for Global Citizenship Elementary School   296   81    27.36   38    12.84    234       79.05
# 1           1            LOCKE, A CHTR     400011  Charter/Contract  All Grades  2013                     213          0.7        -0.1 to 1.5                  81        Yellow                  213       1.0      0.5 to 1.5               87      Green            Alain Locke Charter Elementary Academy   588    1     0.17   36     6.12    552       93.88
# 2           2          AMANDLA CHTR HS     400012  Charter/Contract  All Grades  2013                     243         -1.9       -2.7 to -1.1                   2           Red                  244      -1.4      -2 to -0.9                7        Red                       Amandla Charter High School   311    0     0.00   42    13.50    298       95.82
# 3           3     ASPIRA CHTR - HAUGAN     400017  Charter/Contract  All Grades  2013                     562          0.4          -0.2 to 1                  71        Yellow                  561       0.5      0.2 to 0.9               73      Green                    ASPIRA Charter - Haugan Campus   578  146    25.26   60    10.38    560       96.89

# %%
# different way, assign x and y
x = result['reading_vam']
y = result['LEPperc']

# that's a tilde
lm = smf.ols(formula='y ~ x', data=result).fit()

result.plot(kind='scatter', x='reading_vam', y='LEPperc',label="Vam v % LEP")
plt.ylim(0, 120)
plt.xlim(-6, 6)
plt.legend()
# plots the trendline
plt.plot(x, lm.params.x*x + lm.params.Intercept, '-')

lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     2.809
# Date:                Mon, 17 Aug 2015   Prob (F-statistic):             0.0944
# Time:                        15:00:56   Log-Likelihood:                -2090.0
# No. Observations:                 488   AIC:                             4184.
# Df Residuals:                     486   BIC:                             4192.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     15.4208      0.796     19.369      0.000        13.856    16.985
# x              1.3804      0.824      1.676      0.094        -0.238     2.999
# ==============================================================================
# Omnibus:                       60.102   Durbin-Watson:                   1.688
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               57.517
# Skew:                           0.772   Prob(JB):                     3.24e-13
# Kurtosis:                       2.333   Cond. No.                         1.06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# different way, assign x and y
x = result['reading_vam']
y = result['IEPperc']

# that's a tilde
lm = smf.ols(formula='y ~ x', data=result).fit()

result.plot(kind='scatter', x='reading_vam', y='IEPperc',label="Vam v % IEP")
plt.ylim(0, 120)
plt.xlim(-6, 6)
plt.legend()
# plots the trendline
plt.plot(x, lm.params.x*x + lm.params.Intercept, '-')

lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                   0.03448
# Date:                Mon, 17 Aug 2015   Prob (F-statistic):              0.853
# Time:                        15:01:19   Log-Likelihood:                -1608.3
# No. Observations:                 488   AIC:                             3221.
# Df Residuals:                     486   BIC:                             3229.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     11.9467      0.297     40.270      0.000        11.364    12.530
# x              0.0570      0.307      0.186      0.853        -0.546     0.660
# ==============================================================================
# Omnibus:                      658.098   Durbin-Watson:                   2.038
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           122465.435
# Skew:                           6.683   Prob(JB):                         0.00
# Kurtosis:                      79.448   Cond. No.                         1.06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# different way, assign x and y
x = result['reading_vam']
y = result['LowIncperc']

# that's a tilde
lm = smf.ols(formula='y ~ x', data=result).fit()

result.plot(kind='scatter', x='reading_vam', y='LowIncperc',label="Vam v % low income")
plt.ylim(0, 120)
plt.xlim(-6, 6)
plt.legend()
# plots the trendline
plt.plot(x, lm.params.x*x + lm.params.Intercept, '-')

lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.015
# Model:                            OLS   Adj. R-squared:                  0.013
# Method:                 Least Squares   F-statistic:                     7.476
# Date:                Mon, 17 Aug 2015   Prob (F-statistic):            0.00648
# Time:                        15:01:54   Log-Likelihood:                -2157.1
# No. Observations:                 488   AIC:                             4318.
# Df Residuals:                     486   BIC:                             4327.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     83.5279      0.913     91.442      0.000        81.733    85.323
# x             -2.5840      0.945     -2.734      0.006        -4.441    -0.727
# ==============================================================================
# Omnibus:                      184.603   Durbin-Watson:                   1.984
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              484.773
# Skew:                          -1.936   Prob(JB):                    5.41e-106
# Kurtosis:                       5.975   Cond. No.                         1.06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
