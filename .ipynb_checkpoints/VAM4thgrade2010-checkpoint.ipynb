# %%
# Import all libraries needed for the tutorial
import pandas as pd
import numpy as np
import psycopg2
import sys
from pandas.io import sql
from pandas.io.sql import read_sql
import statsmodels.api as sm
import statsmodels.formula.api as smf

#pd.set_option('display.mpl_style', 'default') 
pd.set_option('display.width', 5000) 
pd.set_option('display.max_columns', 60)

import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

print('Python version ' + sys.version)
print('Pandas version ' + pd.__version__)
# Out:
# Python version 3.4.3 |Anaconda 2.2.0 (x86_64)| (default, Mar  6 2015, 12:07:41)
# [GCC 4.2.1 (Apple Inc. build 5577)]
# Pandas version 0.16.1

# %%
con = psycopg2.connect("dbname=testdb user=tim")  
#cur = con.cursor()
print("con is open")
# Out:
# con is open

# %%
sql = "SELECT * FROM vam JOIN chiisat ON vam.school_id = chiisat.school_id WHERE vam.grade = %s AND vam.year = %s AND chiisat.grade = %s AND chiisat.year = %s ORDER BY vam.school_id;"

data = pd.read_sql(sql, con, index_col=None, coerce_float=True, params=['4th Grade','2010','4th Grade','2010'], parse_dates=None, columns=None, chunksize=None)

if con:
    con.close()

data[:3]
# Out:
#                        school_name school_id                network      grade  year  reading_studentsnumber  reading_vam reading_confidence  reading_percentile reading_color  math_studentsnumber  math_vam math_confidence  math_percentile math_color                      school_name school_id  unit  network      grade  year  readme  mathme  compme  readexc  mathexc  compexc  readmeet  mathmeet  compmeet  readblw  mathblw  compblw  readwrn  mathwrn  compwrn  readtst  mathtst
# 0                    LOCKE, A CHTR    400011      Garfield-Humboldt  4th Grade  2010                    45.0          0.2        -0.7 to 1.1                  59        yellow                 45.0       0.5     -0.2 to 1.2               74     yellow                    LOCKE, A CHTR    400011  4730  Charter  4th Grade  2010    79.2    91.7    79.9     14.6     22.9     15.3      64.6      68.8      64.6     20.8      8.3     19.4        0        0      0.7       48       48
# 1  BRONZEVILLE LTHOUSE CHTR CAMPUS    400019           Burnham Park  4th Grade  2010                    42.5          0.8        -0.1 to 1.7                  84        yellow                 42.5       0.2     -0.4 to 0.9               60     yellow  BRONZEVILLE LTHOUSE CHTR CAMPUS    400019  3990  Charter  4th Grade  2010    55.1    67.3    53.1      6.1      6.1      4.1      49.0      61.2      49.0     44.9     30.6     42.2        0        2      4.8       49       49
# 2          CATALYST CHTR - HOWLAND    400020  Austin-North Lawndale  4th Grade  2010                    29.5          1.3         0.3 to 2.3                  91         green                 29.5       0.8        0 to 1.6               82      green          CATALYST CHTR - HOWLAND    400020  4370  Charter  4th Grade  2010    68.8    71.9    63.5      0.0      0.0      0.0      68.8      71.9      63.5     31.3     28.1     36.5        0        0      0.0       32       32

# %%
data.dtypes
#Check if sql request was successful - yes, number matches that found in excel
#data.info()
# Out:
# school_name                object
# school_id                  object
# network                    object
# grade                      object
# year                       object
# reading_studentsnumber    float64
# reading_vam               float64
# reading_confidence         object
# reading_percentile        float64
# reading_color              object
# math_studentsnumber       float64
# math_vam                  float64
# math_confidence            object
# math_percentile           float64
# math_color                 object
# school_name                object
# school_id                  object
# unit                       object
# network                    object
# grade                      object
# year                       object
# readme                    float64
# mathme                    float64
# compme                    float64
# readexc                   float64
# mathexc                   float64
# compexc                   float64
# readmeet                  float64
# mathmeet                  float64
# compmeet                  float64
# readblw                   float64
# mathblw                   float64
# compblw                   float64
# readwrn                   float64
# mathwrn                   float64
# compwrn                   float64
# readtst                   float64
# mathtst                   float64
# dtype: object

# %%
data.shape
# Out:
# (417, 38)

# %%
x = data['reading_vam']
y = data['readme']

# that's a tilde
lm = smf.ols(formula='y ~ x', data=data).fit()

data.plot(kind='scatter', x='reading_vam', y='readme',label="Reading M/E")
plt.ylim(0, 120)
plt.xlim(-6, 6)
plt.legend()
# plots the trendline
plt.plot(x, lm.params.x*x + lm.params.Intercept, '-')

lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.246
# Model:                            OLS   Adj. R-squared:                  0.244
# Method:                 Least Squares   F-statistic:                     134.9
# Date:                Sat, 15 Aug 2015   Prob (F-statistic):           3.41e-27
# Time:                        21:53:51   Log-Likelihood:                -1722.4
# No. Observations:                 416   AIC:                             3449.
# Df Residuals:                     414   BIC:                             3457.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     59.6224      0.749     79.623      0.000        58.150    61.094
# x              8.7132      0.750     11.616      0.000         7.239    10.188
# ==============================================================================
# Omnibus:                        1.972   Durbin-Watson:                   2.006
# Prob(Omnibus):                  0.373   Jarque-Bera (JB):                1.882
# Skew:                           0.092   Prob(JB):                        0.390
# Kurtosis:                       2.727   Cond. No.                         1.07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x = data['reading_vam']
y = data['readexc']

# that's a tilde
lm = smf.ols(formula='y ~ x', data=data).fit()

data.plot(kind='scatter', x='reading_vam', y='readexc',label="Reading exceeds")
plt.ylim(0, 120)
plt.xlim(-6, 6)

plt.legend()
# plots the trendline
plt.plot(x, lm.params.x*x + lm.params.Intercept, '-')

lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.263
# Model:                            OLS   Adj. R-squared:                  0.261
# Method:                 Least Squares   F-statistic:                     147.5
# Date:                Sat, 15 Aug 2015   Prob (F-statistic):           3.10e-29
# Time:                        21:53:57   Log-Likelihood:                -1703.4
# No. Observations:                 416   AIC:                             3411.
# Df Residuals:                     414   BIC:                             3419.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     16.8696      0.715     23.582      0.000        15.463    18.276
# x              8.7016      0.717     12.143      0.000         7.293    10.110
# ==============================================================================
# Omnibus:                      120.523   Durbin-Watson:                   2.077
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              293.224
# Skew:                           1.444   Prob(JB):                     2.12e-64
# Kurtosis:                       5.928   Cond. No.                         1.07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x = data['reading_vam']
y = data['readmeet']

# that's a tilde
lm = smf.ols(formula='y ~ x', data=data).fit()

data.plot(kind='scatter', x='reading_vam', y='readmeet',label="Reading meets")
plt.ylim(0, 120)
plt.xlim(-6, 6)

plt.legend()
# plots the trendline
plt.plot(x, lm.params.x*x + lm.params.Intercept, '-')

lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                 0.0005206
# Date:                Sat, 15 Aug 2015   Prob (F-statistic):              0.982
# Time:                        21:54:05   Log-Likelihood:                -1566.1
# No. Observations:                 416   AIC:                             3136.
# Df Residuals:                     414   BIC:                             3144.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     42.7574      0.514     83.134      0.000        41.746    43.768
# x              0.0118      0.515      0.023      0.982        -1.001     1.024
# ==============================================================================
# Omnibus:                       48.218   Durbin-Watson:                   1.890
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              109.424
# Skew:                          -0.611   Prob(JB):                     1.73e-24
# Kurtosis:                       5.195   Cond. No.                         1.07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x = data['reading_vam']
y = data['readblw']

# that's a tilde
lm = smf.ols(formula='y ~ x', data=data).fit()

data.plot(kind='scatter', x='reading_vam', y='readblw',label="Reading Below")
plt.ylim(0, 120)
plt.xlim(-6, 6)

plt.legend()
# plots the trendline
plt.plot(x, lm.params.x*x + lm.params.Intercept, '-')

lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.232
# Model:                            OLS   Adj. R-squared:                  0.231
# Method:                 Least Squares   F-statistic:                     125.4
# Date:                Sat, 15 Aug 2015   Prob (F-statistic):           1.32e-25
# Time:                        21:54:11   Log-Likelihood:                -1699.8
# No. Observations:                 416   AIC:                             3404.
# Df Residuals:                     414   BIC:                             3412.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     37.8592      0.709     53.383      0.000        36.465    39.253
# x             -7.9550      0.710    -11.198      0.000        -9.351    -6.559
# ==============================================================================
# Omnibus:                        0.131   Durbin-Watson:                   2.028
# Prob(Omnibus):                  0.937   Jarque-Bera (JB):                0.216
# Skew:                          -0.033   Prob(JB):                        0.898
# Kurtosis:                       2.911   Cond. No.                         1.07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x = data['reading_vam']
y = data['readwrn']

# that's a tilde
lm = smf.ols(formula='y ~ x', data=data).fit()

data.plot(kind='scatter', x='reading_vam', y='readwrn',label="Reading warn")
plt.ylim(0, 120)
plt.xlim(-6, 6)

plt.legend()
# plots the trendline
plt.plot(x, lm.params.x*x + lm.params.Intercept, '-')

lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.078
# Model:                            OLS   Adj. R-squared:                  0.076
# Method:                 Least Squares   F-statistic:                     35.08
# Date:                Sat, 15 Aug 2015   Prob (F-statistic):           6.64e-09
# Time:                        21:54:17   Log-Likelihood:                -987.67
# No. Observations:                 416   AIC:                             1979.
# Df Residuals:                     414   BIC:                             1987.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      2.5213      0.128     19.691      0.000         2.270     2.773
# x             -0.7597      0.128     -5.923      0.000        -1.012    -0.508
# ==============================================================================
# Omnibus:                       94.239   Durbin-Watson:                   1.681
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              178.187
# Skew:                           1.250   Prob(JB):                     2.03e-39
# Kurtosis:                       5.006   Cond. No.                         1.07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x = data['math_vam']
y = data['mathme']

# that's a tilde
lm = smf.ols(formula='y ~ x', data=data).fit()
#print(lm.params.Intercept)
#print(lm.params.x)
#print(lm.params)

data.plot(kind='scatter', x='math_vam', y='mathme',label="Math ME")
plt.ylim(0, 120)
plt.xlim(-6, 6)

plt.legend()
# plots the trendline
plt.plot(x, lm.params.x*x + lm.params.Intercept, '-')

lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.206
# Model:                            OLS   Adj. R-squared:                  0.204
# Method:                 Least Squares   F-statistic:                     107.4
# Date:                Sat, 15 Aug 2015   Prob (F-statistic):           1.54e-22
# Time:                        21:54:24   Log-Likelihood:                -1658.6
# No. Observations:                 417   AIC:                             3321.
# Df Residuals:                     415   BIC:                             3329.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     75.7208      0.635    119.234      0.000        74.472    76.969
# x              6.6223      0.639     10.365      0.000         5.366     7.878
# ==============================================================================
# Omnibus:                       12.233   Durbin-Watson:                   1.993
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               12.538
# Skew:                          -0.419   Prob(JB):                      0.00189
# Kurtosis:                       3.142   Cond. No.                         1.06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x = data['math_vam']
y = data['mathexc']

# that's a tilde
lm = smf.ols(formula='y ~ x', data=data).fit()

data.plot(kind='scatter', x='math_vam', y='mathexc',label="Math Exceeds")
plt.ylim(0, 120)
plt.xlim(-6, 6)

plt.legend()
# plots the trendline
plt.plot(x, lm.params.x*x + lm.params.Intercept, '-')

lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.172
# Model:                            OLS   Adj. R-squared:                  0.170
# Method:                 Least Squares   F-statistic:                     86.04
# Date:                Sat, 15 Aug 2015   Prob (F-statistic):           9.82e-19
# Time:                        21:54:30   Log-Likelihood:                -1728.3
# No. Observations:                 417   AIC:                             3461.
# Df Residuals:                     415   BIC:                             3469.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     15.5913      0.751     20.771      0.000        14.116    17.067
# x              7.0051      0.755      9.276      0.000         5.521     8.490
# ==============================================================================
# Omnibus:                      198.082   Durbin-Watson:                   2.091
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              970.030
# Skew:                           2.068   Prob(JB):                    2.29e-211
# Kurtosis:                       9.223   Cond. No.                         1.06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x = data['math_vam']
y = data['mathmeet']

# that's a tilde
lm = smf.ols(formula='y ~ x', data=data).fit()

data.plot(kind='scatter', x='math_vam', y='mathmeet',label="Math Meets")
plt.ylim(0, 120)
plt.xlim(-6, 6)

plt.legend()
# plots the trendline
plt.plot(x, lm.params.x*x + lm.params.Intercept, '-')

lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.3995
# Date:                Sat, 15 Aug 2015   Prob (F-statistic):              0.528
# Time:                        21:54:37   Log-Likelihood:                -1636.0
# No. Observations:                 417   AIC:                             3276.
# Df Residuals:                     415   BIC:                             3284.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     60.1240      0.602     99.943      0.000        58.941    61.307
# x             -0.3825      0.605     -0.632      0.528        -1.572     0.807
# ==============================================================================
# Omnibus:                      105.119   Durbin-Watson:                   2.004
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              284.746
# Skew:                          -1.204   Prob(JB):                     1.47e-62
# Kurtosis:                       6.255   Cond. No.                         1.06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x = data['math_vam']
y = data['mathblw']

# that's a tilde
lm = smf.ols(formula='y ~ x', data=data).fit()

data.plot(kind='scatter', x='math_vam', y='mathblw',label="Math below")
plt.ylim(0, 120)
plt.xlim(-6, 6)

plt.legend()
# plots the trendline
plt.plot(x, lm.params.x*x + lm.params.Intercept, '-')

lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.188
# Model:                            OLS   Adj. R-squared:                  0.187
# Method:                 Least Squares   F-statistic:                     96.37
# Date:                Sat, 15 Aug 2015   Prob (F-statistic):           1.36e-20
# Time:                        21:54:43   Log-Likelihood:                -1609.6
# No. Observations:                 417   AIC:                             3223.
# Df Residuals:                     415   BIC:                             3231.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     21.6679      0.565     38.374      0.000        20.558    22.778
# x             -5.5769      0.568     -9.817      0.000        -6.694    -4.460
# ==============================================================================
# Omnibus:                       14.884   Durbin-Watson:                   2.077
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               15.462
# Skew:                           0.454   Prob(JB):                     0.000439
# Kurtosis:                       3.254   Cond. No.                         1.06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x = data['math_vam']
y = data['mathwrn']

# that's a tilde
lm = smf.ols(formula='y ~ x', data=data).fit()

data.plot(kind='scatter', x='math_vam', y='mathwrn',label="Math Warn")
plt.ylim(0, 120)
plt.xlim(-6, 6)

plt.legend()
# plots the trendline
plt.plot(x, lm.params.x*x + lm.params.Intercept, '-')

lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.115
# Model:                            OLS   Adj. R-squared:                  0.113
# Method:                 Least Squares   F-statistic:                     53.94
# Date:                Sat, 15 Aug 2015   Prob (F-statistic):           1.10e-12
# Time:                        21:54:49   Log-Likelihood:                -1033.4
# No. Observations:                 417   AIC:                             2071.
# Df Residuals:                     415   BIC:                             2079.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      2.6142      0.142     18.433      0.000         2.335     2.893
# x             -1.0480      0.143     -7.345      0.000        -1.328    -0.768
# ==============================================================================
# Omnibus:                      140.443   Durbin-Watson:                   1.736
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              452.935
# Skew:                           1.546   Prob(JB):                     4.43e-99
# Kurtosis:                       7.063   Cond. No.                         1.06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
