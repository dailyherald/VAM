# %%
# Import all libraries needed for the tutorial
import pandas as pd
import numpy as np
import psycopg2
import sys
from pandas.io import sql
from pandas.io.sql import read_sql
import statsmodels.api as sm
import statsmodels.formula.api as smf

#pd.set_option('display.mpl_style', 'default') 
pd.set_option('display.width', 5000) 
pd.set_option('display.max_columns', 60)

import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

print('Python version ' + sys.version)
print('Pandas version ' + pd.__version__)
# Out:
# Python version 3.4.3 |Anaconda 2.2.0 (x86_64)| (default, Mar  6 2015, 12:07:41)
# [GCC 4.2.1 (Apple Inc. build 5577)]
# Pandas version 0.16.1

# %%
con = psycopg2.connect("dbname=testdb user=tim")  
#cur = con.cursor()
print("con is open")
# Out:
# con is open

# %%
sql = "SELECT * FROM vam JOIN chiisat ON vam.school_id = chiisat.school_id WHERE vam.grade = %s AND vam.year = %s AND chiisat.grade = %s AND chiisat.year = %s ORDER BY vam.school_id;"

data = pd.read_sql(sql, con, index_col=None, coerce_float=True, params=['5th Grade','2013','5th Grade','2013'], parse_dates=None, columns=None, chunksize=None)

if con:
    con.close()

data[:3]
# Out:
#                school_name school_id           network      grade  year  reading_studentsnumber  reading_vam reading_confidence  reading_percentile reading_color  math_studentsnumber  math_vam math_confidence  math_percentile math_color              school_name school_id  unit  network      grade  year  readme  mathme  compme  readexc  mathexc  compexc  readmeet  mathmeet  compmeet  readblw  mathblw  compblw  readwrn  mathwrn  compwrn  readtst  mathtst
# 0  GLOBAL CITIZENSHIP CHTR    400009  Charter/Contract  5th Grade  2013                      46          0.4        -0.7 to 1.4                  65        Yellow                   46       0.1     -0.5 to 0.7               54     Yellow  GLOBAL CITIZENSHIP CHTR    400009  2025  Charter  5th Grade  2013    47.8    43.5    45.7     13.0      2.2      7.6      34.8      41.3      38.0     45.7     43.5     44.6      6.5     13.0      9.8       46       46
# 1            LOCKE, A CHTR    400011  Charter/Contract  5th Grade  2013                      39          0.6        -0.4 to 1.7                  80        Yellow                   39       1.4        0.7 to 2               92      Green            LOCKE, A CHTR    400011  4730  Charter  5th Grade  2013    75.0    67.5    71.3     10.0      7.5      8.8      65.0      60.0      62.5     25.0     32.5     28.8      0.0      0.0      0.0       40       40
# 2          AMANDLA CHTR HS    400012  Charter/Contract  5th Grade  2013                      38          0.4        -0.7 to 1.5                  68        Yellow                   37      -0.6     -1.3 to 0.2               28     Yellow          AMANDLA CHTR HS    400012  2035  Charter  5th Grade  2013    25.6    23.1    24.4      2.6      0.0      1.3      23.1      23.1      23.1     59.0     48.7     53.8     15.4     28.2     21.8       39       39

# %%
data.dtypes
#Check if sql request was successful - yes, number matches that found in excel
#data.info()
# Out:
# school_name                object
# school_id                  object
# network                    object
# grade                      object
# year                       object
# reading_studentsnumber    float64
# reading_vam               float64
# reading_confidence         object
# reading_percentile        float64
# reading_color              object
# math_studentsnumber       float64
# math_vam                  float64
# math_confidence            object
# math_percentile           float64
# math_color                 object
# school_name                object
# school_id                  object
# unit                       object
# network                    object
# grade                      object
# year                       object
# readme                    float64
# mathme                    float64
# compme                    float64
# readexc                   float64
# mathexc                   float64
# compexc                   float64
# readmeet                  float64
# mathmeet                  float64
# compmeet                  float64
# readblw                   float64
# mathblw                   float64
# compblw                   float64
# readwrn                   float64
# mathwrn                   float64
# compwrn                   float64
# readtst                   float64
# mathtst                   float64
# dtype: object

# %%
data.shape
# Out:
# (458, 38)

# %%
x = data['reading_vam']
y = data['readme']

# that's a tilde
lm = smf.ols(formula='y ~ x', data=data).fit()

data.plot(kind='scatter', x='reading_vam', y='readme',label="Reading M/E - 10.1%")
plt.ylim(0, 120)
plt.xlim(-6, 6)

plt.legend()
# plots the trendline
plt.plot(x, lm.params.x*x + lm.params.Intercept, '-')

lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.103
# Model:                            OLS   Adj. R-squared:                  0.101
# Method:                 Least Squares   F-statistic:                     51.80
# Date:                Sat, 15 Aug 2015   Prob (F-statistic):           2.59e-12
# Time:                        22:18:35   Log-Likelihood:                -1958.1
# No. Observations:                 452   AIC:                             3920.
# Df Residuals:                     450   BIC:                             3928.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     43.6338      0.869     50.228      0.000        41.927    45.341
# x              7.3142      1.016      7.197      0.000         5.317     9.311
# ==============================================================================
# Omnibus:                       21.137   Durbin-Watson:                   1.980
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               22.940
# Skew:                           0.547   Prob(JB):                     1.04e-05
# Kurtosis:                       3.143   Cond. No.                         1.18
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x = data['reading_vam']
y = data['readexc']

# that's a tilde
lm = smf.ols(formula='y ~ x', data=data).fit()

data.plot(kind='scatter', x='reading_vam', y='readexc',label="Reading exceeds - 8.9%")
plt.ylim(0, 120)
plt.xlim(-6, 6)

plt.legend()
# plots the trendline
plt.plot(x, lm.params.x*x + lm.params.Intercept, '-')

lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.091
# Model:                            OLS   Adj. R-squared:                  0.089
# Method:                 Least Squares   F-statistic:                     44.90
# Date:                Sat, 15 Aug 2015   Prob (F-statistic):           6.23e-11
# Time:                        22:20:19   Log-Likelihood:                -1760.7
# No. Observations:                 452   AIC:                             3525.
# Df Residuals:                     450   BIC:                             3534.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      9.4612      0.561     16.858      0.000         8.358    10.564
# x              4.3993      0.657      6.700      0.000         3.109     5.690
# ==============================================================================
# Omnibus:                      274.860   Durbin-Watson:                   2.056
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2213.608
# Skew:                           2.593   Prob(JB):                         0.00
# Kurtosis:                      12.520   Cond. No.                         1.18
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x = data['reading_vam']
y = data['readmeet']

# that's a tilde
lm = smf.ols(formula='y ~ x', data=data).fit()

data.plot(kind='scatter', x='reading_vam', y='readmeet',label="Reading meets - 4.1%")
plt.ylim(0, 120)
plt.xlim(-6, 6)

plt.legend()
# plots the trendline
plt.plot(x, lm.params.x*x + lm.params.Intercept, '-')

lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.044
# Model:                            OLS   Adj. R-squared:                  0.041
# Method:                 Least Squares   F-statistic:                     20.47
# Date:                Sat, 15 Aug 2015   Prob (F-statistic):           7.74e-06
# Time:                        22:21:42   Log-Likelihood:                -1752.5
# No. Observations:                 452   AIC:                             3509.
# Df Residuals:                     450   BIC:                             3517.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     34.1714      0.551     61.990      0.000        33.088    35.255
# x              2.9180      0.645      4.525      0.000         1.651     4.185
# ==============================================================================
# Omnibus:                        0.256   Durbin-Watson:                   1.982
# Prob(Omnibus):                  0.880   Jarque-Bera (JB):                0.310
# Skew:                           0.056   Prob(JB):                        0.857
# Kurtosis:                       2.936   Cond. No.                         1.18
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x = data['reading_vam']
y = data['readblw']

# that's a tilde
lm = smf.ols(formula='y ~ x', data=data).fit()

data.plot(kind='scatter', x='reading_vam', y='readblw',label="Reading Below - 7.4%")
plt.ylim(0, 120)
plt.xlim(-6, 6)

plt.legend()
# plots the trendline
plt.plot(x, lm.params.x*x + lm.params.Intercept, '-')

lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.076
# Model:                            OLS   Adj. R-squared:                  0.074
# Method:                 Least Squares   F-statistic:                     36.99
# Date:                Sat, 15 Aug 2015   Prob (F-statistic):           2.54e-09
# Time:                        22:22:42   Log-Likelihood:                -1843.9
# No. Observations:                 452   AIC:                             3692.
# Df Residuals:                     450   BIC:                             3700.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     45.4337      0.675     67.330      0.000        44.108    46.760
# x             -4.8009      0.789     -6.082      0.000        -6.352    -3.249
# ==============================================================================
# Omnibus:                       16.257   Durbin-Watson:                   1.982
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               17.908
# Skew:                          -0.405   Prob(JB):                     0.000129
# Kurtosis:                       3.542   Cond. No.                         1.18
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x = data['reading_vam']
y = data['readwrn']

# that's a tilde
lm = smf.ols(formula='y ~ x', data=data).fit()

data.plot(kind='scatter', x='reading_vam', y='readwrn',label="Reading warn - 7.3%")
plt.ylim(0, 120)
plt.xlim(-6, 6)

plt.legend()
# plots the trendline
plt.plot(x, lm.params.x*x + lm.params.Intercept, '-')

lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.075
# Model:                            OLS   Adj. R-squared:                  0.073
# Method:                 Least Squares   F-statistic:                     36.33
# Date:                Sat, 15 Aug 2015   Prob (F-statistic):           3.48e-09
# Time:                        22:23:48   Log-Likelihood:                -1555.4
# No. Observations:                 452   AIC:                             3115.
# Df Residuals:                     450   BIC:                             3123.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     10.9340      0.356     30.682      0.000        10.234    11.634
# x             -2.5127      0.417     -6.027      0.000        -3.332    -1.693
# ==============================================================================
# Omnibus:                       40.006   Durbin-Watson:                   1.901
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               50.138
# Skew:                           0.709   Prob(JB):                     1.30e-11
# Kurtosis:                       3.806   Cond. No.                         1.18
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x = data['math_vam']
y = data['mathme']

# that's a tilde
lm = smf.ols(formula='y ~ x', data=data).fit()
#print(lm.params.Intercept)
#print(lm.params.x)
#print(lm.params)

data.plot(kind='scatter', x='math_vam', y='mathme',label="Math ME")
plt.ylim(0, 120)
plt.xlim(-6, 8)

plt.legend()
# plots the trendline
plt.plot(x, lm.params.x*x + lm.params.Intercept, '-')

lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.267
# Model:                            OLS   Adj. R-squared:                  0.265
# Method:                 Least Squares   F-statistic:                     164.0
# Date:                Sat, 15 Aug 2015   Prob (F-statistic):           3.15e-32
# Time:                        21:24:37   Log-Likelihood:                -1940.5
# No. Observations:                 452   AIC:                             3885.
# Df Residuals:                     450   BIC:                             3893.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     48.6932      0.836     58.267      0.000        47.051    50.336
# x             11.0140      0.860     12.805      0.000         9.324    12.704
# ==============================================================================
# Omnibus:                        8.207   Durbin-Watson:                   1.886
# Prob(Omnibus):                  0.017   Jarque-Bera (JB):                5.931
# Skew:                           0.157   Prob(JB):                       0.0515
# Kurtosis:                       2.535   Cond. No.                         1.05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x = data['math_vam']
y = data['mathexc']

# that's a tilde
lm = smf.ols(formula='y ~ x', data=data).fit()

data.plot(kind='scatter', x='math_vam', y='mathexc',label="Math Exceeds")
plt.ylim(0, 120)
plt.xlim(-6, 8)

plt.legend()
# plots the trendline
plt.plot(x, lm.params.x*x + lm.params.Intercept, '-')

lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.172
# Model:                            OLS   Adj. R-squared:                  0.170
# Method:                 Least Squares   F-statistic:                     93.67
# Date:                Sat, 15 Aug 2015   Prob (F-statistic):           2.98e-20
# Time:                        21:25:01   Log-Likelihood:                -1673.8
# No. Observations:                 452   AIC:                             3352.
# Df Residuals:                     450   BIC:                             3360.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      6.9705      0.463     15.047      0.000         6.060     7.881
# x              4.6146      0.477      9.679      0.000         3.678     5.552
# ==============================================================================
# Omnibus:                      282.939   Durbin-Watson:                   2.130
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2332.079
# Skew:                           2.687   Prob(JB):                         0.00
# Kurtosis:                      12.744   Cond. No.                         1.05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x = data['math_vam']
y = data['mathmeet']

# that's a tilde
lm = smf.ols(formula='y ~ x', data=data).fit()

data.plot(kind='scatter', x='math_vam', y='mathmeet',label="Math Meets")
plt.ylim(0, 120)
plt.xlim(-6, 8)

plt.legend()
# plots the trendline
plt.plot(x, lm.params.x*x + lm.params.Intercept, '-')

lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.176
# Model:                            OLS   Adj. R-squared:                  0.175
# Method:                 Least Squares   F-statistic:                     96.43
# Date:                Sat, 15 Aug 2015   Prob (F-statistic):           9.45e-21
# Time:                        21:25:24   Log-Likelihood:                -1815.1
# No. Observations:                 452   AIC:                             3634.
# Df Residuals:                     450   BIC:                             3642.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     41.7215      0.633     65.894      0.000        40.477    42.966
# x              6.3991      0.652      9.820      0.000         5.118     7.680
# ==============================================================================
# Omnibus:                        6.495   Durbin-Watson:                   1.804
# Prob(Omnibus):                  0.039   Jarque-Bera (JB):                4.246
# Skew:                          -0.048   Prob(JB):                        0.120
# Kurtosis:                       2.535   Cond. No.                         1.05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x = data['math_vam']
y = data['mathblw']

# that's a tilde
lm = smf.ols(formula='y ~ x', data=data).fit()

data.plot(kind='scatter', x='math_vam', y='mathblw',label="Math below")
plt.ylim(0, 120)
plt.xlim(-6, 8)

plt.legend()
# plots the trendline
plt.plot(x, lm.params.x*x + lm.params.Intercept, '-')

lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.225
# Model:                            OLS   Adj. R-squared:                  0.223
# Method:                 Least Squares   F-statistic:                     130.3
# Date:                Sat, 15 Aug 2015   Prob (F-statistic):           1.10e-26
# Time:                        21:25:42   Log-Likelihood:                -1815.0
# No. Observations:                 452   AIC:                             3634.
# Df Residuals:                     450   BIC:                             3642.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     40.5045      0.633     63.977      0.000        39.260    41.749
# x             -7.4390      0.652    -11.416      0.000        -8.720    -6.158
# ==============================================================================
# Omnibus:                        3.360   Durbin-Watson:                   1.949
# Prob(Omnibus):                  0.186   Jarque-Bera (JB):                3.313
# Skew:                          -0.170   Prob(JB):                        0.191
# Kurtosis:                       2.755   Cond. No.                         1.05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x = data['math_vam']
y = data['mathwrn']

# that's a tilde
lm = smf.ols(formula='y ~ x', data=data).fit()

data.plot(kind='scatter', x='math_vam', y='mathwrn',label="Math Warn")
plt.ylim(0, 120)
plt.xlim(-6, 8)

plt.legend()
# plots the trendline
plt.plot(x, lm.params.x*x + lm.params.Intercept, '-')

lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.157
# Model:                            OLS   Adj. R-squared:                  0.156
# Method:                 Least Squares   F-statistic:                     84.05
# Date:                Sat, 15 Aug 2015   Prob (F-statistic):           1.73e-18
# Time:                        21:26:06   Log-Likelihood:                -1582.7
# No. Observations:                 452   AIC:                             3169.
# Df Residuals:                     450   BIC:                             3178.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     10.8044      0.379     28.534      0.000        10.060    11.548
# x             -3.5728      0.390     -9.168      0.000        -4.339    -2.807
# ==============================================================================
# Omnibus:                       57.299   Durbin-Watson:                   1.880
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               76.462
# Skew:                           0.929   Prob(JB):                     2.49e-17
# Kurtosis:                       3.779   Cond. No.                         1.05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
