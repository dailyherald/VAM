# %%
# Import all libraries needed for the tutorial
import pandas as pd
import numpy as np
import psycopg2
import sys
from pandas.io import sql
from pandas.io.sql import read_sql
import statsmodels.formula.api as smf

#pd.set_option('display.mpl_style', 'default') 
pd.set_option('display.width', 5000) 
pd.set_option('display.max_columns', 60)

import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

print('Python version ' + sys.version)
print('Pandas version ' + pd.__version__)
# Out:
# Python version 3.4.3 |Anaconda 2.2.0 (x86_64)| (default, Mar  6 2015, 12:07:41)
# [GCC 4.2.1 (Apple Inc. build 5577)]
# Pandas version 0.16.1

# %%
con = psycopg2.connect("dbname=testdb user=tim")  
#cur = con.cursor()
print("con is open")
# Out:
# con is open

# %%
sql = "SELECT * FROM vam JOIN chiisat ON vam.school_id = chiisat.school_id WHERE vam.grade = %s AND vam.year = %s AND chiisat.grade = %s AND chiisat.year = %s ORDER BY vam.school_id;"

data = pd.read_sql(sql, con, index_col=None, coerce_float=True, params=['6th Grade','2011','6th Grade','2011'], parse_dates=None, columns=None, chunksize=None)

if con:
    con.close()

data[:3]
# Out:
#             school_name school_id                    network      grade  year  reading_studentsnumber  reading_vam reading_confidence  reading_percentile reading_color  math_studentsnumber  math_vam math_confidence  math_percentile math_color           school_name school_id  unit  network      grade  year  readme  mathme  compme  readexc  mathexc  compexc  readmeet  mathmeet  compmeet  readblw  mathblw  compblw  readwrn  mathwrn  compwrn  readtst  mathtst
# 0         LOCKE, A CHTR    400011          Garfield-Humboldt  6th Grade  2011                    43.4         -0.4        -1.4 to 0.6                  34        yellow                 43.4      -0.3     -0.9 to 0.4               39     yellow         LOCKE, A CHTR    400011  4730  Charter  6th Grade  2011    97.7    95.5    96.6     45.5     36.4     40.9      52.3      59.1      55.7      2.3      4.5      3.4        0        0      0.0       44       44
# 1       AMANDLA CHTR HS    400012  Southwest Side HS Network  6th Grade  2011                    84.4          0.5        -0.4 to 1.3                  65        yellow                 84.4       1.5          1 to 2               92      green       AMANDLA CHTR HS    400012  2035  Charter  6th Grade  2011    76.0    80.2    78.1     14.6     15.6     15.1      61.5      64.6      63.0     24.0     18.8     21.4        0        1      0.5       96       96
# 2  ASPIRA CHTR - HAUGAN    400017                     O'Hare  6th Grade  2011                    88.1         -1.3       -2.1 to -0.5                  10           red                 88.1      -1.3    -1.8 to -0.8                8        red  ASPIRA CHTR - HAUGAN    400017  3500  Charter  6th Grade  2011    71.0    72.6    71.8      9.7      5.6      7.7      61.3      66.9      64.1     29.0     27.4     28.2        0        0      0.0      124      124

# %%
data.dtypes
#Check if sql request was successful - yes, number matches that found in excel
#data.info()
# Out:
# school_name                object
# school_id                  object
# network                    object
# grade                      object
# year                       object
# reading_studentsnumber    float64
# reading_vam               float64
# reading_confidence         object
# reading_percentile        float64
# reading_color              object
# math_studentsnumber       float64
# math_vam                  float64
# math_confidence            object
# math_percentile           float64
# math_color                 object
# school_name                object
# school_id                  object
# unit                       object
# network                    object
# grade                      object
# year                       object
# readme                    float64
# mathme                    float64
# compme                    float64
# readexc                   float64
# mathexc                   float64
# compexc                   float64
# readmeet                  float64
# mathmeet                  float64
# compmeet                  float64
# readblw                   float64
# mathblw                   float64
# compblw                   float64
# readwrn                   float64
# mathwrn                   float64
# compwrn                   float64
# readtst                   float64
# mathtst                   float64
# dtype: object

# %%
data.shape
# Out:
# (434, 38)

# %%
x = data['reading_vam']
y = data['readme']

# that's a tilde
lm = smf.ols(formula='y ~ x', data=data).fit()

data.plot(kind='scatter', x='reading_vam', y='readme',label="Reading M/E")
plt.ylim(0, 120)
plt.xlim(-6, 8)
plt.legend()
# plots the trendline
plt.plot(x, lm.params.x*x + lm.params.Intercept, '-')

lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.179
# Model:                            OLS   Adj. R-squared:                  0.177
# Method:                 Least Squares   F-statistic:                     93.98
# Date:                Sat, 15 Aug 2015   Prob (F-statistic):           3.08e-20
# Time:                        21:27:55   Log-Likelihood:                -1692.5
# No. Observations:                 434   AIC:                             3389.
# Df Residuals:                     432   BIC:                             3397.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     76.6409      0.575    133.196      0.000        75.510    77.772
# x              5.5213      0.570      9.694      0.000         4.402     6.641
# ==============================================================================
# Omnibus:                        2.799   Durbin-Watson:                   2.051
# Prob(Omnibus):                  0.247   Jarque-Bera (JB):                2.474
# Skew:                          -0.097   Prob(JB):                        0.290
# Kurtosis:                       2.685   Cond. No.                         1.04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x = data['reading_vam']
y = data['readexc']

# that's a tilde
lm = smf.ols(formula='y ~ x', data=data).fit()

data.plot(kind='scatter', x='reading_vam', y='readexc',label="Reading Exceeds")
plt.ylim(0, 120)
plt.legend()
# plots the trendline
plt.plot(x, lm.params.x*x + lm.params.Intercept, '-')

lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.123
# Model:                            OLS   Adj. R-squared:                  0.120
# Method:                 Least Squares   F-statistic:                     60.31
# Date:                Sat, 15 Aug 2015   Prob (F-statistic):           5.95e-14
# Time:                        21:28:04   Log-Likelihood:                -1812.3
# No. Observations:                 434   AIC:                             3629.
# Df Residuals:                     432   BIC:                             3637.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     18.8860      0.758     24.906      0.000        17.396    20.376
# x              5.8287      0.751      7.766      0.000         4.353     7.304
# ==============================================================================
# Omnibus:                      207.816   Durbin-Watson:                   2.127
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              989.952
# Skew:                           2.113   Prob(JB):                    1.08e-215
# Kurtosis:                       9.074   Cond. No.                         1.04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x = data['reading_vam']
y = data['readmeet']

# that's a tilde
lm = smf.ols(formula='y ~ x', data=data).fit()

data.plot(kind='scatter', x='reading_vam', y='readmeet',label="Reading Meets")
plt.ylim(0, 120)
plt.legend()
# plots the trendline
plt.plot(x, lm.params.x*x + lm.params.Intercept, '-')

lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                    0.3054
# Date:                Sat, 15 Aug 2015   Prob (F-statistic):              0.581
# Time:                        21:28:09   Log-Likelihood:                -1679.6
# No. Observations:                 434   AIC:                             3363.
# Df Residuals:                     432   BIC:                             3371.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     57.7553      0.558    103.414      0.000        56.658    58.853
# x             -0.3055      0.553     -0.553      0.581        -1.392     0.781
# ==============================================================================
# Omnibus:                      123.866   Durbin-Watson:                   1.846
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              361.915
# Skew:                          -1.340   Prob(JB):                     2.58e-79
# Kurtosis:                       6.582   Cond. No.                         1.04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x = data['reading_vam']
y = data['readblw']

# that's a tilde
lm = smf.ols(formula='y ~ x', data=data).fit()

data.plot(kind='scatter', x='reading_vam', y='readblw',label="Reading Below")
plt.ylim(0, 120)
plt.legend()
# plots the trendline
plt.plot(x, lm.params.x*x + lm.params.Intercept, '-')

lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.178
# Model:                            OLS   Adj. R-squared:                  0.176
# Method:                 Least Squares   F-statistic:                     93.76
# Date:                Sat, 15 Aug 2015   Prob (F-statistic):           3.37e-20
# Time:                        21:28:14   Log-Likelihood:                -1683.4
# No. Observations:                 434   AIC:                             3371.
# Df Residuals:                     432   BIC:                             3379.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     22.9758      0.563     40.780      0.000        21.868    24.083
# x             -5.3999      0.558     -9.683      0.000        -6.496    -4.304
# ==============================================================================
# Omnibus:                        3.321   Durbin-Watson:                   2.045
# Prob(Omnibus):                  0.190   Jarque-Bera (JB):                2.715
# Skew:                           0.079   Prob(JB):                        0.257
# Kurtosis:                       2.647   Cond. No.                         1.04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x = data['reading_vam']
y = data['readwrn']

# that's a tilde
lm = smf.ols(formula='y ~ x', data=data).fit()

data.plot(kind='scatter', x='reading_vam', y='readwrn',label="Reading Warn")
plt.ylim(0, 120)
plt.legend()
# plots the trendline
plt.plot(x, lm.params.x*x + lm.params.Intercept, '-')

lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.015
# Model:                            OLS   Adj. R-squared:                  0.013
# Method:                 Least Squares   F-statistic:                     6.623
# Date:                Sat, 15 Aug 2015   Prob (F-statistic):             0.0104
# Time:                        21:28:18   Log-Likelihood:                -610.26
# No. Observations:                 434   AIC:                             1225.
# Df Residuals:                     432   BIC:                             1233.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      0.3846      0.048      8.092      0.000         0.291     0.478
# x             -0.1211      0.047     -2.573      0.010        -0.214    -0.029
# ==============================================================================
# Omnibus:                      357.382   Durbin-Watson:                   1.982
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5793.279
# Skew:                           3.573   Prob(JB):                         0.00
# Kurtosis:                      19.411   Cond. No.                         1.04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x = data['math_vam']
y = data['mathme']

# that's a tilde
lm = smf.ols(formula='y ~ x', data=data).fit()

data.plot(kind='scatter', x='math_vam', y='mathme',label="Math M/E")
plt.ylim(0, 120)
plt.legend()
# plots the trendline
plt.plot(x, lm.params.x*x + lm.params.Intercept, '-')

lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.078
# Model:                            OLS   Adj. R-squared:                  0.076
# Method:                 Least Squares   F-statistic:                     36.60
# Date:                Sat, 15 Aug 2015   Prob (F-statistic):           3.14e-09
# Time:                        21:29:35   Log-Likelihood:                -1743.7
# No. Observations:                 434   AIC:                             3491.
# Df Residuals:                     432   BIC:                             3500.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     75.3761      0.648    116.259      0.000        74.102    76.650
# x              3.8635      0.639      6.050      0.000         2.608     5.119
# ==============================================================================
# Omnibus:                        9.091   Durbin-Watson:                   2.014
# Prob(Omnibus):                  0.011   Jarque-Bera (JB):                9.402
# Skew:                          -0.350   Prob(JB):                      0.00909
# Kurtosis:                       2.829   Cond. No.                         1.07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x = data['math_vam']
y = data['mathexc']

# that's a tilde
lm = smf.ols(formula='y ~ x', data=data).fit()

data.plot(kind='scatter', x='math_vam', y='mathexc',label="Math Exceeds")
plt.ylim(0, 120)
plt.legend()
# plots the trendline
plt.plot(x, lm.params.x*x + lm.params.Intercept, '-')

lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.068
# Model:                            OLS   Adj. R-squared:                  0.065
# Method:                 Least Squares   F-statistic:                     31.28
# Date:                Sat, 15 Aug 2015   Prob (F-statistic):           3.97e-08
# Time:                        21:29:56   Log-Likelihood:                -1801.6
# No. Observations:                 434   AIC:                             3607.
# Df Residuals:                     432   BIC:                             3615.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     17.0774      0.741     23.051      0.000        15.621    18.533
# x              4.0811      0.730      5.593      0.000         2.647     5.515
# ==============================================================================
# Omnibus:                      175.016   Durbin-Watson:                   2.078
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              618.811
# Skew:                           1.856   Prob(JB):                    4.23e-135
# Kurtosis:                       7.521   Cond. No.                         1.07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x = data['math_vam']
y = data['mathmeet']

# that's a tilde
lm = smf.ols(formula='y ~ x', data=data).fit()

data.plot(kind='scatter', x='math_vam', y='mathmeet',label="Math Meets")
plt.ylim(0, 120)
plt.legend()
# plots the trendline
plt.plot(x, lm.params.x*x + lm.params.Intercept, '-')

lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                    0.1635
# Date:                Sat, 15 Aug 2015   Prob (F-statistic):              0.686
# Time:                        21:30:03   Log-Likelihood:                -1674.0
# No. Observations:                 434   AIC:                             3352.
# Df Residuals:                     432   BIC:                             3360.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     58.2993      0.552    105.587      0.000        57.214    59.385
# x             -0.2199      0.544     -0.404      0.686        -1.289     0.849
# ==============================================================================
# Omnibus:                       73.255   Durbin-Watson:                   1.974
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              141.730
# Skew:                          -0.938   Prob(JB):                     1.67e-31
# Kurtosis:                       5.079   Cond. No.                         1.07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x = data['math_vam']
y = data['mathblw']

# that's a tilde
lm = smf.ols(formula='y ~ x', data=data).fit()

data.plot(kind='scatter', x='math_vam', y='mathblw',label="Math Below")
plt.ylim(0, 120)
plt.legend()
# plots the trendline
plt.plot(x, lm.params.x*x + lm.params.Intercept, '-')

lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.078
# Model:                            OLS   Adj. R-squared:                  0.076
# Method:                 Least Squares   F-statistic:                     36.36
# Date:                Sat, 15 Aug 2015   Prob (F-statistic):           3.52e-09
# Time:                        21:30:14   Log-Likelihood:                -1724.1
# No. Observations:                 434   AIC:                             3452.
# Df Residuals:                     432   BIC:                             3460.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     23.5831      0.620     38.051      0.000        22.365    24.801
# x             -3.6810      0.610     -6.030      0.000        -4.881    -2.481
# ==============================================================================
# Omnibus:                       10.447   Durbin-Watson:                   2.023
# Prob(Omnibus):                  0.005   Jarque-Bera (JB):               10.788
# Skew:                           0.386   Prob(JB):                      0.00454
# Kurtosis:                       2.986   Cond. No.                         1.07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x = data['math_vam']
y = data['mathwrn']

# that's a tilde
lm = smf.ols(formula='y ~ x', data=data).fit()

data.plot(kind='scatter', x='math_vam', y='mathwrn',label="Math Warn")
plt.ylim(0, 120)
plt.legend()
# plots the trendline
plt.plot(x, lm.params.x*x + lm.params.Intercept, '-')

lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.011
# Model:                            OLS   Adj. R-squared:                  0.008
# Method:                 Least Squares   F-statistic:                     4.702
# Date:                Sat, 15 Aug 2015   Prob (F-statistic):             0.0307
# Time:                        21:30:21   Log-Likelihood:                -862.11
# No. Observations:                 434   AIC:                             1728.
# Df Residuals:                     432   BIC:                             1736.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      1.0397      0.085     12.225      0.000         0.873     1.207
# x             -0.1816      0.084     -2.168      0.031        -0.346    -0.017
# ==============================================================================
# Omnibus:                      325.854   Durbin-Watson:                   1.952
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5572.082
# Skew:                           3.078   Prob(JB):                         0.00
# Kurtosis:                      19.439   Cond. No.                         1.07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
