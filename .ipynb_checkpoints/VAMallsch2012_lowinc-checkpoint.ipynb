# %%
# Import all libraries needed for the tutorial
import pandas as pd
import numpy as np
import psycopg2
import sys
from pandas.io import sql
from pandas.io.sql import read_sql
import statsmodels.api as sm
import statsmodels.formula.api as smf

#pd.set_option('display.mpl_style', 'default') 
pd.set_option('display.width', 5000) 
pd.set_option('display.max_columns', 60)

import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

print('This Python version ' + sys.version)
print('Pandas version ' + pd.__version__)
# Out:
# This Python version 3.4.3 |Anaconda 2.2.0 (x86_64)| (default, Mar  6 2015, 12:07:41)
# [GCC 4.2.1 (Apple Inc. build 5577)]
# Pandas version 0.16.1

# %%
data = pd.DataFrame.from_csv('data2012.csv', index_col=None)
low = pd.DataFrame.from_csv('lowinc_2012.csv', index_col=None, encoding='ISO-8859-1')

# %%
data[:4]
# Out:
#    Unnamed: 0              school_name  school_id                   network       grade  year  reading_studentsnumber  reading_vam reading_confidence  reading_percentile reading_color  math_studentsnumber  math_vam math_confidence  math_percentile math_color
# 0           0  GLOBAL CITIZENSHIP CHTR     400009  Charter/Contract Schools  All Grades  2012                    34.7          1.0        -0.4 to 2.3                  84        Yellow                 34.7       0.0       -1.1 to 1               51     Yellow
# 1           1            LOCKE, A CHTR     400011  Charter/Contract Schools  All Grades  2012                   202.7         -1.0       -1.9 to -0.1                  14           Red                202.7       0.1     -0.4 to 0.6               57     Yellow
# 2           2          AMANDLA CHTR HS     400012  Charter/Contract Schools  All Grades  2012                   276.9         -0.9       -1.8 to -0.1                  16           Red                277.9      -0.5         -1 to 0               28        Red
# 3           3     ASPIRA CHTR - HAUGAN     400017  Charter/Contract Schools  All Grades  2012                   468.7         -1.0       -1.7 to -0.3                  14           Red                468.6      -0.4       -0.8 to 0               30        Red

# %%
data.dtypes
# Out:
# Unnamed: 0                  int64
# school_name                object
# school_id                   int64
# network                    object
# grade                      object
# year                        int64
# reading_studentsnumber    float64
# reading_vam               float64
# reading_confidence         object
# reading_percentile        float64
# reading_color              object
# math_studentsnumber       float64
# math_vam                  float64
# math_confidence            object
# math_percentile           float64
# math_color                 object
# dtype: object

# %%
low[:4]
# Out:
#    school_id                                       School Name Total  LEP  LEPperc  IEP  IEPperc LowInc  LowIncperc
# 0     610229                              A.N. Pritzker School   668   45     6.74   69    10.33    412       61.68
# 1     610038                 Abraham Lincoln Elementary School   809   46     5.69   56     6.92    107       13.23
# 2     400009  Academy for Global Citizenship Elementary School   247   87    35.22   34    13.77    197       79.76
# 3     610281  Adam Clayton Powell Paideia Community Academy ES   520   10     1.92   53    10.19    505       97.12

# %%
low.dtypes
# Out:
# school_id        int64
# School Name     object
# Total           object
# LEP              int64
# LEPperc        float64
# IEP              int64
# IEPperc        float64
# LowInc          object
# LowIncperc     float64
# dtype: object

# %%
left = data
right = low
result = pd.merge(left, right, on='school_id')
result.shape
# Out:
# (532, 24)

# %%
result[:4]
# Out:
#    Unnamed: 0              school_name  school_id                   network       grade  year  reading_studentsnumber  reading_vam reading_confidence  reading_percentile reading_color  math_studentsnumber  math_vam math_confidence  math_percentile math_color                                       School Name Total  LEP  LEPperc  IEP  IEPperc LowInc  LowIncperc
# 0           0  GLOBAL CITIZENSHIP CHTR     400009  Charter/Contract Schools  All Grades  2012                    34.7          1.0        -0.4 to 2.3                  84        Yellow                 34.7       0.0       -1.1 to 1               51     Yellow  Academy for Global Citizenship Elementary School   247   87    35.22   34    13.77    197       79.76
# 1           1            LOCKE, A CHTR     400011  Charter/Contract Schools  All Grades  2012                   202.7         -1.0       -1.9 to -0.1                  14           Red                202.7       0.1     -0.4 to 0.6               57     Yellow            Alain Locke Charter Elementary Academy   588    1     0.17   31     5.27    527       89.63
# 2           2          AMANDLA CHTR HS     400012  Charter/Contract Schools  All Grades  2012                   276.9         -0.9       -1.8 to -0.1                  16           Red                277.9      -0.5         -1 to 0               28        Red                       Amandla Charter High School   348    0     0.00   48    13.79    335       96.26
# 3           3     ASPIRA CHTR - HAUGAN     400017  Charter/Contract Schools  All Grades  2012                   468.7         -1.0       -1.7 to -0.3                  14           Red                468.6      -0.4       -0.8 to 0               30        Red                    ASPIRA Charter - Haugan Campus   592  132    22.30   71    11.99    585       98.82

# %%
# different way, assign x and y
x = result['reading_vam']
y = result['LEPperc']

# that's a tilde
lm = smf.ols(formula='y ~ x', data=result).fit()

result.plot(kind='scatter', x='reading_vam', y='LEPperc',label="Vam v % LEP")
plt.ylim(0, 120)
plt.xlim(-6, 6)
plt.legend()
# plots the trendline
plt.plot(x, lm.params.x*x + lm.params.Intercept, '-')

lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     2.865
# Date:                Mon, 17 Aug 2015   Prob (F-statistic):             0.0911
# Time:                        15:06:54   Log-Likelihood:                -2269.1
# No. Observations:                 532   AIC:                             4542.
# Df Residuals:                     530   BIC:                             4551.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     14.2496      0.748     19.047      0.000        12.780    15.719
# x              1.2278      0.725      1.693      0.091        -0.197     2.653
# ==============================================================================
# Omnibus:                       62.740   Durbin-Watson:                   1.689
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               79.693
# Skew:                           0.929   Prob(JB):                     4.95e-18
# Kurtosis:                       2.618   Cond. No.                         1.03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# different way, assign x and y
x = result['math_vam']
y = result['LEPperc']

# that's a tilde
lm = smf.ols(formula='y ~ x', data=result).fit()

result.plot(kind='scatter', x='math_vam', y='LEPperc',label="Vam v % LEP")
plt.ylim(0, 120)
plt.xlim(-6, 6)
plt.legend()
# plots the trendline
plt.plot(x, lm.params.x*x + lm.params.Intercept, '-')

lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                   0.09954
# Date:                Mon, 17 Aug 2015   Prob (F-statistic):              0.753
# Time:                        15:09:51   Log-Likelihood:                -2270.5
# No. Observations:                 532   AIC:                             4545.
# Df Residuals:                     530   BIC:                             4554.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     14.2490      0.750     18.996      0.000        12.775    15.723
# x              0.2227      0.706      0.315      0.753        -1.164     1.609
# ==============================================================================
# Omnibus:                       63.751   Durbin-Watson:                   1.692
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               80.036
# Skew:                           0.927   Prob(JB):                     4.17e-18
# Kurtosis:                       2.583   Cond. No.                         1.06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# different way, assign x and y
x = result['reading_vam']
y = result['IEPperc']

# that's a tilde
lm = smf.ols(formula='y ~ x', data=result).fit()

result.plot(kind='scatter', x='reading_vam', y='IEPperc',label="Vam v % IEP")
plt.ylim(0, 120)
plt.xlim(-6, 6)
plt.legend()
# plots the trendline
plt.plot(x, lm.params.x*x + lm.params.Intercept, '-')

lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.4829
# Date:                Mon, 17 Aug 2015   Prob (F-statistic):              0.487
# Time:                        15:07:01   Log-Likelihood:                -1890.1
# No. Observations:                 532   AIC:                             3784.
# Df Residuals:                     530   BIC:                             3793.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     12.3391      0.367     33.629      0.000        11.618    13.060
# x             -0.2472      0.356     -0.695      0.487        -0.946     0.452
# ==============================================================================
# Omnibus:                      722.687   Durbin-Watson:                   2.005
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           102592.854
# Skew:                           7.019   Prob(JB):                         0.00
# Kurtosis:                      69.567   Cond. No.                         1.03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# different way, assign x and y
x = result['math_vam']
y = result['IEPperc']

# that's a tilde
lm = smf.ols(formula='y ~ x', data=result).fit()

result.plot(kind='scatter', x='math_vam', y='IEPperc',label="Vam v % IEP")
plt.ylim(0, 120)
plt.xlim(-6, 6)
plt.legend()
# plots the trendline
plt.plot(x, lm.params.x*x + lm.params.Intercept, '-')

lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     1.791
# Date:                Mon, 17 Aug 2015   Prob (F-statistic):              0.181
# Time:                        15:08:21   Log-Likelihood:                -1889.4
# No. Observations:                 532   AIC:                             3783.
# Df Residuals:                     530   BIC:                             3791.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     12.3360      0.366     33.661      0.000        11.616    13.056
# x             -0.4614      0.345     -1.338      0.181        -1.139     0.216
# ==============================================================================
# Omnibus:                      723.449   Durbin-Watson:                   2.009
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           103326.665
# Skew:                           7.031   Prob(JB):                         0.00
# Kurtosis:                      69.810   Cond. No.                         1.06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# different way, assign x and y
x = result['reading_vam']
y = result['LowIncperc']

# that's a tilde
lm = smf.ols(formula='y ~ x', data=result).fit()

result.plot(kind='scatter', x='reading_vam', y='LowIncperc',label="Vam v % low income")
plt.ylim(0, 120)
plt.xlim(-6, 6)
plt.legend()
# plots the trendline
plt.plot(x, lm.params.x*x + lm.params.Intercept, '-')

lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.076
# Model:                            OLS   Adj. R-squared:                  0.074
# Method:                 Least Squares   F-statistic:                     43.47
# Date:                Mon, 17 Aug 2015   Prob (F-statistic):           1.04e-10
# Time:                        15:07:10   Log-Likelihood:                -2311.4
# No. Observations:                 532   AIC:                             4627.
# Df Residuals:                     530   BIC:                             4635.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     85.6139      0.810    105.694      0.000        84.023    87.205
# x             -5.1777      0.785     -6.593      0.000        -6.720    -3.635
# ==============================================================================
# Omnibus:                      205.456   Durbin-Watson:                   1.975
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              584.932
# Skew:                          -1.936   Prob(JB):                    9.63e-128
# Kurtosis:                       6.377   Cond. No.                         1.03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# different way, assign x and y
x = result['math_vam']
y = result['LowIncperc']

# that's a tilde
lm = smf.ols(formula='y ~ x', data=result).fit()

result.plot(kind='scatter', x='math_vam', y='LowIncperc',label="Vam v % low income")
plt.ylim(0, 120)
plt.xlim(-6, 6)
plt.legend()
# plots the trendline
plt.plot(x, lm.params.x*x + lm.params.Intercept, '-')

lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                     3.702
# Date:                Mon, 17 Aug 2015   Prob (F-statistic):             0.0549
# Time:                        15:08:53   Log-Likelihood:                -2330.5
# No. Observations:                 532   AIC:                             4665.
# Df Residuals:                     530   BIC:                             4674.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     85.6119      0.840    101.959      0.000        83.962    87.261
# x             -1.5199      0.790     -1.924      0.055        -3.072     0.032
# ==============================================================================
# Omnibus:                      236.144   Durbin-Watson:                   2.009
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              784.476
# Skew:                          -2.175   Prob(JB):                    4.50e-171
# Kurtosis:                       7.057   Cond. No.                         1.06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
