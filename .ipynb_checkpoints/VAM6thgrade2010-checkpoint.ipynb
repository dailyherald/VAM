# %%
# Import all libraries needed for the tutorial
import pandas as pd
import numpy as np
import psycopg2
import sys
from pandas.io import sql
from pandas.io.sql import read_sql
import statsmodels.formula.api as smf

#pd.set_option('display.mpl_style', 'default') 
pd.set_option('display.width', 5000) 
pd.set_option('display.max_columns', 60)

import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

print('Python version ' + sys.version)
print('Pandas version ' + pd.__version__)
# Out:
# Python version 3.4.3 |Anaconda 2.2.0 (x86_64)| (default, Mar  6 2015, 12:07:41)
# [GCC 4.2.1 (Apple Inc. build 5577)]
# Pandas version 0.16.1

# %%
con = psycopg2.connect("dbname=testdb user=tim")  
#cur = con.cursor()
print("con is open")
# Out:
# con is open

# %%
sql = "SELECT * FROM vam JOIN chiisat ON vam.school_id = chiisat.school_id WHERE vam.grade = %s AND vam.year = %s AND chiisat.grade = %s AND chiisat.year = %s ORDER BY vam.school_id;"

data = pd.read_sql(sql, con, index_col=None, coerce_float=True, params=['6th Grade','2010','6th Grade','2010'], parse_dates=None, columns=None, chunksize=None)

if con:
    con.close()

data[:3]
# Out:
#             school_name school_id                    network      grade  year  reading_studentsnumber  reading_vam reading_confidence  reading_percentile reading_color  math_studentsnumber  math_vam math_confidence  math_percentile math_color           school_name school_id  unit  network      grade  year  readme  mathme  compme  readexc  mathexc  compexc  readmeet  mathmeet  compmeet  readblw  mathblw  compblw  readwrn  mathwrn  compwrn  readtst  mathtst
# 0         LOCKE, A CHTR    400011          Garfield-Humboldt  6th Grade  2010                    42.0         -0.5        -1.6 to 0.6                  29        yellow                 42.0      -0.3       -1 to 0.5               40     yellow         LOCKE, A CHTR    400011  4730  Charter  6th Grade  2010      81    85.7    83.3     21.4     14.3     17.9      59.5      71.4      65.5       19     14.3     16.7        0        0      0.0       42       42
# 1       AMANDLA CHTR HS    400012  Southwest Side HS Network  6th Grade  2010                    92.9          1.5         0.7 to 2.3                  95         green                 92.9       1.6      1.1 to 2.1               93      green       AMANDLA CHTR HS    400012  2035  Charter  6th Grade  2010      73    71.0    72.0     13.0     10.0     11.5      60.0      61.0      60.5       27     26.0     26.5        0        3      1.5      100      100
# 2  ASPIRA CHTR - HAUGAN    400017                     O'Hare  6th Grade  2010                    58.3         -1.8       -2.8 to -0.9                   2           red                 58.3      -0.8    -1.5 to -0.1               22        red  ASPIRA CHTR - HAUGAN    400017  3500  Charter  6th Grade  2010      57    61.0    59.0      8.0     10.0      9.0      49.0      51.0      50.0       40     37.0     38.5        3        2      2.5      100      100

# %%
data.dtypes
#Check if sql request was successful - yes, number matches that found in excel
#data.info()
# Out:
# school_name                object
# school_id                  object
# network                    object
# grade                      object
# year                       object
# reading_studentsnumber    float64
# reading_vam               float64
# reading_confidence         object
# reading_percentile        float64
# reading_color              object
# math_studentsnumber       float64
# math_vam                  float64
# math_confidence            object
# math_percentile           float64
# math_color                 object
# school_name                object
# school_id                  object
# unit                       object
# network                    object
# grade                      object
# year                       object
# readme                    float64
# mathme                    float64
# compme                    float64
# readexc                   float64
# mathexc                   float64
# compexc                   float64
# readmeet                  float64
# mathmeet                  float64
# compmeet                  float64
# readblw                   float64
# mathblw                   float64
# compblw                   float64
# readwrn                   float64
# mathwrn                   float64
# compwrn                   float64
# readtst                   float64
# mathtst                   float64
# dtype: object

# %%
data.shape
# Out:
# (426, 38)

# %%
x = data['reading_vam']
y = data['readme']

# that's a tilde
lm = smf.ols(formula='y ~ x', data=data).fit()

data.plot(kind='scatter', x='reading_vam', y='readme',label="Reading M/E")
plt.ylim(0, 120)
plt.xlim(-6, 8)
plt.legend()
# plots the trendline
plt.plot(x, lm.params.x*x + lm.params.Intercept, '-')

lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.178
# Model:                            OLS   Adj. R-squared:                  0.176
# Method:                 Least Squares   F-statistic:                     91.97
# Date:                Mon, 03 Aug 2015   Prob (F-statistic):           7.65e-20
# Time:                        16:50:47   Log-Likelihood:                -1738.0
# No. Observations:                 426   AIC:                             3480.
# Df Residuals:                     424   BIC:                             3488.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     70.2441      0.695    101.014      0.000        68.877    71.611
# x              6.5021      0.678      9.590      0.000         5.169     7.835
# ==============================================================================
# Omnibus:                        4.759   Durbin-Watson:                   2.053
# Prob(Omnibus):                  0.093   Jarque-Bera (JB):                4.673
# Skew:                          -0.220   Prob(JB):                       0.0967
# Kurtosis:                       2.736   Cond. No.                         1.04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x = data['reading_vam']
y = data['readexc']

# that's a tilde
lm = smf.ols(formula='y ~ x', data=data).fit()

data.plot(kind='scatter', x='reading_vam', y='readexc',label="Reading Exceeds")
plt.ylim(0, 120)
plt.legend()
# plots the trendline
plt.plot(x, lm.params.x*x + lm.params.Intercept, '-')

lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.174
# Model:                            OLS   Adj. R-squared:                  0.172
# Method:                 Least Squares   F-statistic:                     89.39
# Date:                Mon, 03 Aug 2015   Prob (F-statistic):           2.23e-19
# Time:                        10:58:50   Log-Likelihood:                -1737.0
# No. Observations:                 426   AIC:                             3478.
# Df Residuals:                     424   BIC:                             3486.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     15.5897      0.694     22.471      0.000        14.226    16.953
# x              6.3953      0.676      9.455      0.000         5.066     7.725
# ==============================================================================
# Omnibus:                      195.009   Durbin-Watson:                   2.122
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              887.267
# Skew:                           2.016   Prob(JB):                    2.15e-193
# Kurtosis:                       8.807   Cond. No.                         1.04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x = data['reading_vam']
y = data['readmeet']

# that's a tilde
lm = smf.ols(formula='y ~ x', data=data).fit()

data.plot(kind='scatter', x='reading_vam', y='readmeet',label="Reading Meets")
plt.ylim(0, 120)
plt.legend()
# plots the trendline
plt.plot(x, lm.params.x*x + lm.params.Intercept, '-')

lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                   0.03659
# Date:                Mon, 03 Aug 2015   Prob (F-statistic):              0.848
# Time:                        10:59:25   Log-Likelihood:                -1657.5
# No. Observations:                 426   AIC:                             3319.
# Df Residuals:                     424   BIC:                             3327.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     54.6527      0.576     94.947      0.000        53.521    55.784
# x              0.1074      0.561      0.191      0.848        -0.996     1.210
# ==============================================================================
# Omnibus:                       59.869   Durbin-Watson:                   1.897
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              125.323
# Skew:                          -0.764   Prob(JB):                     6.12e-28
# Kurtosis:                       5.173   Cond. No.                         1.04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x = data['reading_vam']
y = data['readblw']

# that's a tilde
lm = smf.ols(formula='y ~ x', data=data).fit()

data.plot(kind='scatter', x='reading_vam', y='readblw',label="Reading Below")
plt.ylim(0, 120)
plt.legend()
# plots the trendline
plt.plot(x, lm.params.x*x + lm.params.Intercept, '-')

lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.173
# Model:                            OLS   Adj. R-squared:                  0.171
# Method:                 Least Squares   F-statistic:                     88.46
# Date:                Mon, 03 Aug 2015   Prob (F-statistic):           3.30e-19
# Time:                        10:59:45   Log-Likelihood:                -1730.5
# No. Observations:                 426   AIC:                             3465.
# Df Residuals:                     424   BIC:                             3473.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     29.2399      0.683     42.796      0.000        27.897    30.583
# x             -6.2655      0.666     -9.405      0.000        -7.575    -4.956
# ==============================================================================
# Omnibus:                        4.602   Durbin-Watson:                   2.065
# Prob(Omnibus):                  0.100   Jarque-Bera (JB):                4.665
# Skew:                           0.235   Prob(JB):                       0.0970
# Kurtosis:                       2.797   Cond. No.                         1.04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x = data['reading_vam']
y = data['readwrn']

# that's a tilde
lm = smf.ols(formula='y ~ x', data=data).fit()

data.plot(kind='scatter', x='reading_vam', y='readwrn',label="Reading Warn")
plt.ylim(0, 120)
plt.legend()
# plots the trendline
plt.plot(x, lm.params.x*x + lm.params.Intercept, '-')

lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.053
# Model:                            OLS   Adj. R-squared:                  0.050
# Method:                 Least Squares   F-statistic:                     23.54
# Date:                Mon, 03 Aug 2015   Prob (F-statistic):           1.72e-06
# Time:                        11:00:04   Log-Likelihood:                -615.39
# No. Observations:                 426   AIC:                             1235.
# Df Residuals:                     424   BIC:                             1243.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      0.5172      0.050     10.374      0.000         0.419     0.615
# x             -0.2359      0.049     -4.852      0.000        -0.331    -0.140
# ==============================================================================
# Omnibus:                      205.294   Durbin-Watson:                   1.926
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              840.025
# Skew:                           2.209   Prob(JB):                    3.90e-183
# Kurtosis:                       8.273   Cond. No.                         1.04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x = data['math_vam']
y = data['mathme']

# that's a tilde
lm = smf.ols(formula='y ~ x', data=data).fit()

data.plot(kind='scatter', x='math_vam', y='mathme',label="Math M/E")
plt.ylim(0, 120)
plt.legend()
# plots the trendline
plt.plot(x, lm.params.x*x + lm.params.Intercept, '-')

lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.107
# Model:                            OLS   Adj. R-squared:                  0.105
# Method:                 Least Squares   F-statistic:                     50.83
# Date:                Sat, 15 Aug 2015   Prob (F-statistic):           4.37e-12
# Time:                        21:31:51   Log-Likelihood:                -1754.2
# No. Observations:                 426   AIC:                             3512.
# Df Residuals:                     424   BIC:                             3521.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     73.8377      0.722    102.280      0.000        72.419    75.257
# x              4.9429      0.693      7.129      0.000         3.580     6.306
# ==============================================================================
# Omnibus:                       15.908   Durbin-Watson:                   2.090
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               16.259
# Skew:                          -0.449   Prob(JB):                     0.000295
# Kurtosis:                       2.669   Cond. No.                         1.04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x = data['math_vam']
y = data['mathexc']

# that's a tilde
lm = smf.ols(formula='y ~ x', data=data).fit()

data.plot(kind='scatter', x='math_vam', y='mathexc',label="Math Exceeds")
plt.ylim(0, 120)
plt.legend()
# plots the trendline
plt.plot(x, lm.params.x*x + lm.params.Intercept, '-')

lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.088
# Model:                            OLS   Adj. R-squared:                  0.086
# Method:                 Least Squares   F-statistic:                     40.94
# Date:                Mon, 03 Aug 2015   Prob (F-statistic):           4.17e-10
# Time:                        11:00:37   Log-Likelihood:                -1738.0
# No. Observations:                 426   AIC:                             3480.
# Df Residuals:                     424   BIC:                             3488.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     14.3738      0.695     20.686      0.000        13.008    15.740
# x              4.2696      0.667      6.398      0.000         2.958     5.581
# ==============================================================================
# Omnibus:                      197.584   Durbin-Watson:                   2.193
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              877.240
# Skew:                           2.062   Prob(JB):                    3.23e-191
# Kurtosis:                       8.694   Cond. No.                         1.04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x = data['math_vam']
y = data['mathmeet']

# that's a tilde
lm = smf.ols(formula='y ~ x', data=data).fit()

data.plot(kind='scatter', x='math_vam', y='mathmeet',label="Math Meets")
plt.ylim(0, 120)
plt.legend()
# plots the trendline
plt.plot(x, lm.params.x*x + lm.params.Intercept, '-')

lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     1.466
# Date:                Mon, 03 Aug 2015   Prob (F-statistic):              0.227
# Time:                        11:01:18   Log-Likelihood:                -1659.2
# No. Observations:                 426   AIC:                             3322.
# Df Residuals:                     424   BIC:                             3331.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     59.4659      0.578    102.956      0.000        58.331    60.601
# x              0.6716      0.555      1.211      0.227        -0.419     1.762
# ==============================================================================
# Omnibus:                       55.364   Durbin-Watson:                   1.922
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               99.486
# Skew:                          -0.768   Prob(JB):                     2.49e-22
# Kurtosis:                       4.802   Cond. No.                         1.04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x = data['math_vam']
y = data['mathblw']

# that's a tilde
lm = smf.ols(formula='y ~ x', data=data).fit()

data.plot(kind='scatter', x='math_vam', y='mathblw',label="Math Below")
plt.ylim(0, 120)
plt.legend()
# plots the trendline
plt.plot(x, lm.params.x*x + lm.params.Intercept, '-')

lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.113
# Model:                            OLS   Adj. R-squared:                  0.111
# Method:                 Least Squares   F-statistic:                     53.97
# Date:                Mon, 03 Aug 2015   Prob (F-statistic):           1.05e-12
# Time:                        11:01:39   Log-Likelihood:                -1731.0
# No. Observations:                 426   AIC:                             3466.
# Df Residuals:                     424   BIC:                             3474.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     24.8736      0.684     36.389      0.000        23.530    26.217
# x             -4.8226      0.656     -7.346      0.000        -6.113    -3.532
# ==============================================================================
# Omnibus:                       15.848   Durbin-Watson:                   2.069
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               16.830
# Skew:                           0.472   Prob(JB):                     0.000221
# Kurtosis:                       2.763   Cond. No.                         1.04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x = data['math_vam']
y = data['mathwrn']

# that's a tilde
lm = smf.ols(formula='y ~ x', data=data).fit()

data.plot(kind='scatter', x='math_vam', y='mathwrn',label="Math Warn")
plt.ylim(0, 120)
plt.legend()
# plots the trendline
plt.plot(x, lm.params.x*x + lm.params.Intercept, '-')

lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     2.036
# Date:                Mon, 03 Aug 2015   Prob (F-statistic):              0.154
# Time:                        11:02:01   Log-Likelihood:                -856.67
# No. Observations:                 426   AIC:                             1717.
# Df Residuals:                     424   BIC:                             1725.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      1.2919      0.088     14.717      0.000         1.119     1.464
# x             -0.1203      0.084     -1.427      0.154        -0.286     0.045
# ==============================================================================
# Omnibus:                      148.754   Durbin-Watson:                   2.119
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              402.755
# Skew:                           1.710   Prob(JB):                     3.49e-88
# Kurtosis:                       6.316   Cond. No.                         1.04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
